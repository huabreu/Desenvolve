# %% [markdown]
# ## Nomes dos alunos e alunas da próxima turma

# %%
import pandas as pd

# %%
matriculas_por_curso = pd.read_csv("matriculas_por_curso.csv")

# %%
matriculas_por_curso
# Out:
#     id_curso  quantidade_de_alunos                        nome_do_curso
# 0          1                   111                Lógica de programação
# 1          2                   170                        Java para Web
# 2          3                    93                          C# para Web
# 3          4                   255                        Ruby on Rails
# 4          5                    55                     Cursos de Python
# 5          6                   128                        PHP com MySql
# 6          7                   103                        .NET para web
# 7          8                    38           Novas integrações com Java
# 8          9                   219                         TDD com Java
# 9         10                   227                  Código limpo com C#
# 10        11                   187  Preparatório para certificação Java
# 11        12                    60                      Hardware básico
# 12        13                   274                Persistência com .NET
# 13        14                    23                  Desenvolvendo jogos
# 14        15                   179                     Análise de dados
# 15        16                    99                   Estatística básica
# 16        17                    54                  Internet das coisas
# 17        18                    69                Programação funcional
# 18        19                    45                Boas práticas em Java
# 19        20                    17          Orientação objetos com Java

# %%
matriculas
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-1922ecfe7e18> in <module>
# ----> 1 matriculas
#
# NameError: name 'matriculas' is not defined
